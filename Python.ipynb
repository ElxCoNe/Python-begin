# %% [markdown]
# <a href="https://colab.research.google.com/github/ElxCoNe/Python-begin/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#declaracion de variables.

claveDep=int
nombre=str

#Solicitud del nombre

print("Digite su nombre; ")
nombre=str(input())

#solicitud de la clave del departamento

print("Digite la clave del departamento, 1- Atencion al cliente, 2- Logistica, 3- Gerencia ")
claveDep=int(input())

#condicional en caso de clave 1

if claveDep==1:
    print("¿Cuantos años de servicio lleva en la empresa?")
    tiempo=int(input())
    if tiempo==1:
        print(nombre + " tienes derecho a 6 dias de vacaciones.")
    elif tiempo in range(2,6):
        print(nombre + " tienes derecho a 14 dias de vacaciones.")
    elif tiempo>=7:
        print(nombre + " tienes derecho a 20 dias de vacaciones.")

#condicional en caso de clave 2

elif claveDep==2:
    print("¿Cuantos años de servicio lleva en la empresa?")
    tiempo=int(input())
    if tiempo==1:
        print(nombre + " tienes derecho a 7 dias de vacaciones.")
    elif tiempo in range(2,6):
        print(nombre + " tienes derecho a 15 dias de vacaciones.")
    elif tiempo>=7:
         print(nombre + " tienes derecho a 22 dias de vacaciones.")

#condicional en caso de clave 3

elif claveDep==3:
    print("¿Cuantos años de servicio lleva en la empresa?")
    tiempo=int(input())
    if tiempo==1:
         print(nombre + " tienes derecho a 10 dias de vacaciones.")
    elif tiempo in range(2,6):
         print(nombre + " tienes derecho a 20 dias de vacaciones.")
    elif tiempo>=7:
        print(nombre + " tienes derecho a 30 dias de vacaciones.")
# Out:
# Digite su nombre;
# Luisa
# Digite la clave del departamento, 1- Atencion al cliente, 2- Logistica, 3- Gerencia
# 1
# ¿Cuantos años de servicio lleva en la empresa?
# 5
# Luisa tienes derecho a 14 dias de vacaciones.

# %% [markdown]
# ![Diagrama de flujo Py_page-0001.jpg](data:image/jpeg;base64,...)
